# %%
#!pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import count

plt.style.use('ggplot')

# %matplotlib inline
# %config InlineBackend.figure_format='svg'

# %%
def load(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    df.sort_values(by='k', ignore_index=True, inplace=True)
    return df

# %%
df = load('results.csv')
df
# Out:
#        k  rank      time
# 0      0     0  0.005160
# 1      1     1  0.005576
# 2      2     2  0.006398
# 3      3     3  0.004149
# 4      4     4  0.004547
# ..   ...   ...       ...
# 955  955     2  0.006505
# 956  956     3  0.004398
# 957  957     4  0.004860
# 958  958     5  0.005438
# 959  959     6  0.005409
#
# [960 rows x 3 columns]

# %% [markdown]
# ## Zadanie 2.

# %%
def zad2(df):
    print('min: ', df['time'].min())
    print('max: ', df['time'].max())
    print('diff:', df['time'].max() - df['time'].min())
    df.plot(x='k', y='time')

# %%
zad2(df)
# Out:
# min:  0.0040744142606854
# max:  0.0409630993381142
# diff: 0.0368886850774288

# %% [markdown]
# ## Zadanie 3.

# %%
def zad3(df):
    fig, ax = plt.subplots(figsize=(32, 4))
    palette = sns.color_palette('plasma', len(df['rank'].unique()))
    colors = df['rank'].map(dict(zip(count(), palette)))
    df.plot(x='k', y='time', kind='bar', width=1, color=colors, ax=ax)
    ax.set_xticks([])

# %%
zad3(df)

# %% [markdown]
# ## Zadanie 4.

# %%
def zad4(df):
    return df.groupby(by='rank').agg({'k': 'count'})

# %%
zad4(df)
# Out:
#         k
# rank
# 0     119
# 1     119
# 2     116
# 3     184
# 4     159
# 5     130
# 6     133

# %%
zad4(df).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='rank'>

# %% [markdown]
# ## Zadanie 5.

# %%
def zad5(df):
    return df.groupby(by='rank').agg({'time': 'sum'})

# %%
zad5(df)
# Out:
#           time
# rank
# 0     2.442373
# 1     2.441269
# 2     2.441182
# 3     2.480085
# 4     2.461694
# 5     2.433357
# 6     2.439909

# %%
zad5(df).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='rank'>

# %% [markdown]
# ## Zadanie 6.

# %%
df2 = load('results_fft.csv')
df2
# Out:
#        k  rank      time
# 0      0     0  0.004709
# 1      1     1  0.004888
# 2      2     2  0.005442
# 3      3     3  0.004938
# 4      4     4  0.004973
# ..   ...   ...       ...
# 955  955     0  0.005057
# 956  956     1  0.005051
# 957  957     2  0.005031
# 958  958     3  0.005035
# 959  959     4  0.004698
#
# [960 rows x 3 columns]

# %%
df2[df2['k'] == 7]
# Out:
#    k  rank      time
# 7  7     6  0.004117

# %%
zad3(df2)

# %%
zad4(df2)
# Out:
#         k
# rank
# 0     153
# 1     152
# 2     153
# 3     152
# 4     147
# 5       4
# 6     199

# %%
zad4(df2).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='rank'>

# %%
zad5(df2)
# Out:
#           time
# rank
# 0     2.721559
# 1     2.707874
# 2     2.707286
# 3     2.669438
# 4     2.685775
# 5     2.949109
# 6     2.717082

# %%
zad5(df2).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='rank'>
